# %% [markdown]
# # RQ2 : Can explicit F/T substitute Implicit Force Modelling?

# %% [markdown]
# ## Task Wipe Board
#
# **Already have:**
# * ACT-Base
# * ACT-Obs Target
#
# **We need:**
# * ACT-Obs Target + Raw Screw-Torque
# * ACT-Obs Target + Adjusted Screw-Torque

# %% [raw]
# Working directory:
#
# /home/khw/ACT_screw_torque

# %% [markdown]
# Train 1:
# * ACT - screw-axis Torque

# %%
python3 imitate_episodes_screw_torque.py \
--task_name board_wipe \
--ckpt_dir ./ckpt_dir/board_wipe_FT  \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 \
> board_wipe_FT.log 2>&1
# Out:
#   Cell In[1], line 1
#     python3 imitate_episodes_screw_torque.py \
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# Train 2:
# * ACT screw torque + Obs_target

# %%
python3 imitate_episodes_screw_torque.py \
--task_name lego_insert \
--ckpt_dir ./ckpt_dir/board_wipe_FT_obs  \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 --use_obs_target \
> lego_insert_obs_target.log 2>&1

# %% [markdown]
# Train 3:
# * ACT **adjusted** screw torque + Obs_target

# %%
python3 imitate_episodes_screw_torque.py \
--task_name lego_insert \
--ckpt_dir ./ckpt_dir/board_wipe_FT_obs  \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 --use_obs_target \
> lego_insert_obs_target.log 2>&1

# %% [markdown]
# ### Extra train

# %% [markdown]
# 1
# * ACT with Adjusted Chunk Size
# * Chunk size should correspond to 1 second wall-clock time

# %% [raw]
# Working directory:
#
# /home/khw/ACT_screw_torque

# %%
python3 imitate_episodes_record_torque.py \
--task_name board_wipe \
--ckpt_dir ./ckpt_dir/board_wipe_chunk50  \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 50 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 \
> board_wipe_chunk50.log 2>&1

# %% [markdown]
# 2
# * ACT in Task Space instead of Configuration Space
# * Task - Board wiping

# %%
# For testing illustration only
python imitate_episodes_record_torque.py \
--task_name board_wipe \
--ckpt_dir ./ckpt_dir/board_wipe_pos_control  \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT_IK \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 4 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 \
> board_wipe_pos_control.log 2>&1

# %% [markdown]
# ### Converting to A6000 training code
#
# We give an example of how to convert to the A6000 configuration parameters.\
# Note currently we do not support anything that uses the Interbotix / ALOHA packages

# %%
# A6000 configuration example

python imitate_episodes_no_ALOHA.py \   ### NOTE
--task_name board_wipe_a6000 \   ### NOTE
--ckpt_dir ./ckpt_dir/board_wipe_chunk50  \  ### NOTE
--robot /home/khw/aloha/config/robot/aloha_solo \   ### NOTE
--policy_class ACT \
--kl_weight 10 \
--chunk_size 50 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 \
> board_wipe_chunk50.log 2>&1

# %%
# A6000 configuration

python imitate_episodes_no_ALOHA.py \
--task_name board_wipe_a6000 \
--ckpt_dir ./ckpt_dir/board_wipe_chunk_POS_CONTROL  \
--robot /home/khw/aloha/config/robot/aloha_solo \
--policy_class ACT_IK \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 \
> board_wipe_POS_CONTROL_a6000.log 2>&1
