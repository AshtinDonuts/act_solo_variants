# %% [markdown]
# ### **Tiny Thesis** - Does ACT lean heavily on the “Leader vs Follower” Joint-Discrepancy for Force Modelling
# **Date:** 2026-02-20
#
# **System:** Conda : act_train

# %% [markdown]
# ### 1. Motivation
#
# **Goal** : Show that ACT does rely very heavily on Joint-State Discrepancy to predict approriate next action, thus accomplishing Force-Aware actions like Plug insertion.

# %% [markdown]
# ## 2. Task design and Hypothesis
#
# ### Task Description
# 1. Plug-Insert - is actually a Plug-adjust task.
# 2. Lego-Insert   := minimal randomization in pose and orientation.
# 3. Lego-Insert-h := requires height generalization since we train on 3 different block heights
#
# #### Task Detailed Configurations
# We perform the below tasks:
# * TASK1: Plug insert 30 eps
#     * Model: ACT Base
#     * Cam Views: 3 views
#
# *  TASK2: Plug insert 30 eps:
#     * Model: ACT Base - Obs joints as Target
#     * Cam Views: 3 views
#     * Dataset: Plug insert 30 eps

# %% [markdown]
# ## 3. Task Design Considerations
# N.A

# %% [markdown]
# ### Task 1 Plug-Insert (aka. Plug Adjust)

# %% [markdown]
# ✅ TRAIN 1:
# * Model: ACT Base
# * Cam Views: 3 views
# * Dataset: Plug insert 30 eps

# %%
# Train Base ACT

nohup python3 imitate_episodes_record_torque.py \
--task_name plug_insert \
--ckpt_dir ./ckpt_dir/plug_insert_base_feb23 \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 8 \
--dim_feedforward 3200 \
--num_epochs 6000 \
--lr 1e-5 --seed 0 \
> plug_insert_base_feb23.log 2>&1

# %% [markdown]
# ✅ TRAIN 2:
# * Model: ACT Base - Obs joints as Target
# * Cam Views: 3 views
# * Dataset: Plug insert 30 eps

# %%
python3 imitate_episodes_record_torque.py \
--task_name plug_insert \
--ckpt_dir ./ckpt_dir/plug_insert_obs_target_feb23 \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 8 \
--dim_feedforward 3200 \
--num_epochs 6000 \
--lr 1e-5 --seed 0 --use_obs_target \
> plug_insert_obs_target_feb23.log 2>&1

# %% [markdown]
# ### Task 2 Lego_insert
#
# This is with 20 episodes, same per CompACT Training Data Collection configurations.
#
# We compare in 2 dimensions:
# 1. Base ACT, vs. using Obs Joints as Target
# 2. Using 1, 2, 3 Camera Views
#
# Comparisons done as Cartesian products for configuration settings.

# %% [markdown]
# Train 1:
# * Model: ACT Base - Obs joints as Target
# * Cam Views: 3 views
# * Dataset: Lego insert 20 eps

# %%
python3 imitate_episodes_record_torque.py \
--task_name lego_insert \
--ckpt_dir ./ckpt_dir/lego_insert_base_feb24 \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 \
> lego_insert_base_feb24.log 2>&1

# %% [markdown]
# 🔄 Train 2:
# * Model: ACT Base - Obs joints as Target
# * Cam Views: 3 views
# * Dataset: Lego insert 20 eps

# %%
python3 imitate_episodes_record_torque.py \
--task_name lego_insert \
--ckpt_dir ./ckpt_dir/lego_insert_obs_target_feb23 \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 --use_obs_target \
> lego_insert_obs_target_feb23.log 2>&1

# %% [markdown]
# 🔄 Train 3:
# * Model: ACT Base
# * Cam Views: 2 views (right shoulder, wrist)
# * Dataset: Lego insert 20 eps

# %% [raw]
# cameras == camera_wrist_left, camera_right_shoulder, camera_left_shoulder

# %%
python3 imitate_episodes_record_torque.py \
--task_name lego_insert \
--ckpt_dir ./ckpt_dir/lego_insert_2view \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 32 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--exclude_cameras camera_left_shoulder \
--lr 3e-5 --seed 0 \
> lego_insert_2view.log 2>&1

# %% [markdown]
# 🔄 Train 4:
# * Model: ACT Base - **Obs joints as Target**
# * Cam Views: 2 views (right shoulder, wrist)
# * Dataset: Lego insert 20 eps

# %%
python3 imitate_episodes_record_torque.py \
--task_name lego_insert \
--ckpt_dir ./ckpt_dir/lego_insert_2view_obs_target \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 32 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--exclude_cameras camera_left_shoulder \
--lr 3e-5 --seed 0 --use_obs_target \
> lego_insert_2view_obs_target.log 2>&1

# %% [markdown]
# 🔄 Train 5:
# * Model: ACT Base
# * Cam Views: 1 views (wrist)
# * Dataset: Lego insert 20 eps

# %%
python3 imitate_episodes_record_torque.py \
--task_name lego_insert \
--ckpt_dir ./ckpt_dir/lego_insert_1view \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 32 \
--dim_feedforward 3200 \
--num_epochs 6000 \
--exclude_cameras camera_right_shoulder camera_left_shoulder \
--lr 3e-5 --seed 0 \
> lego_insert_1view.log 2>&1

# %% [markdown]
# 🔄 Train 6:
# * Model: ACT Base - **Obs joints as Target**
# * Cam Views: 1 views ( wrist)
# * Dataset: Lego insert 20 eps

# %%
python3 imitate_episodes_record_torque.py \
--task_name lego_insert \
--ckpt_dir ./ckpt_dir/lego_insert_1view_obs_target \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 32 \
--dim_feedforward 3200 \
--num_epochs 6000 \
--exclude_cameras camera_right_shoulder camera_left_shoulder \
--lr 3e-5 --seed 0 --use_obs_target \
> lego_insert_1view_obs_target.log 2>&1

# %% [markdown]
# ### Task 3 Lego_insert_h

# %% [markdown]
# ## 5. Evaluation

# %% [markdown]
# **Success** ... sort of\
# worked for initial realignment when there are strong visual cues for changes + non-quasi static state.\
# Doesn't do the final step insertion.
