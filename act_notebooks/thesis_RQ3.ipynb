# %% [markdown]
# # RQ2 : What's a suitable representation of F/T?
#
# We will mainly compare:
# *

# %% [markdown]
# ## 1. Training
#
# All training runs use base training settings, unless otherwise stated.
#
# **Cameras**:\
# Hard to decide... but let's go with 2 cameras, because then:
# * Room for improvement
# * We can logically jump to wrist-cam only setup

# %% [markdown]
# Train 1:
# * ACT - screw-axis Torque

# %%
python3 imitate_episodes_screw_torque.py \
--task_name board_wipe \
--ckpt_dir ./ckpt_dir/board_wipe_FT  \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 \
> board_wipe_FT.log 2>&1
# Out:
#   Cell In[1], line 1
#     python3 imitate_episodes_screw_torque.py \
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# Train 2:
# * ACT screw torque + Obs_target

# %%
python3 imitate_episodes_screw_torque.py \
--task_name lego_insert \
--ckpt_dir ./ckpt_dir/board_wipe_FT_obs  \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 --use_obs_target \
> lego_insert_obs_target.log 2>&1

# %% [markdown]
# Train 2b:
# * ACT **adjusted** screw torque + Obs_target

# %%
python3 imitate_episodes_screw_torque.py \
--task_name lego_insert \
--ckpt_dir ./ckpt_dir/board_wipe_FT_obs  \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 --use_obs_target \
> lego_insert_obs_target.log 2>&1

# %% [markdown]
# Train 3A:
# * ACT raw EEF F/T + Obs_target
# * Let's assume EEF F/T works best with Task Space, thereby reducing the gridsearch.

# %%
python3 imitate_episodes_screw_torque.py \
--task_name lego_insert \
--ckpt_dir ./ckpt_dir/board_wipe_FT_EEF_obs  \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 --use_obs_target \
> lego_insert_obs_target.log 2>&1

# %% [markdown]
# Train 3B:
# * ACT **Adjusted** EEF F/T + Obs_target
# * Let's assume EEF F/T works best with Task Space, thereby reducing the gridsearch.

# %%
python3 imitate_episodes_screw_torque.py \
--task_name lego_insert \
--ckpt_dir ./ckpt_dir/board_wipe_FT_EEF_obs  \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 --use_obs_target \
> lego_insert_obs_target.log 2>&1
