# %% [markdown]
# Not a Tiny thesis... just running some experiments

# %% [markdown]
# Train 1:
# * Model: ACT Base - Obs joints as Target
# * Cam Views: 3 views

# %%
python3 imitate_episodes_record_torque.py \
--task_name soap_push \
--ckpt_dir ./ckpt_dir/soap_push \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 \
> soap_push.log 2>&1

# %% [markdown]
# 🔄 Train 2:
# * Model: ACT Base - Obs joints as Target
# * Cam Views: 3 views

# %%
python3 imitate_episodes_record_torque.py \
--task_name soap_push \
--ckpt_dir ./ckpt_dir/soap_push_obs_target \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 --use_obs_target \
> soap_push_obs_target.log 2>&1

# %% [markdown]
# 🔄 Train 3:
# * Model: ACT Base
# * Cam Views: 2 views (right shoulder, wrist)

# %% [raw]
# cameras == camera_wrist_left, camera_right_shoulder, camera_left_shoulder

# %%
python3 imitate_episodes_record_torque.py \
--task_name soap_push \
--ckpt_dir ./ckpt_dir/soap_push_2view \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--exclude_cameras camera_left_shoulder \
--lr 2e-5 --seed 0 \
> soap_push_2view.log 2>&1

# %% [markdown]
# 🔄 Train 4:
# * Model: ACT Base - **Obs joints as Target**
# * Cam Views: 2 views (right shoulder, wrist)

# %%
python3 imitate_episodes_record_torque.py \
--task_name lego_insert_h \
--ckpt_dir ./ckpt_dir/lego_insert_h_2view_obs_target \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--exclude_cameras camera_left_shoulder \
--lr 2e-5 --seed 0 --use_obs_target \
> lego_insert_h_2view_obs_target.log 2>&1

# %% [markdown]
# 🔄 Train 5:
# * Model: ACT Base
# * Cam Views: 1 views (wrist)

# %%
python3 imitate_episodes_record_torque.py \
--task_name soap_push \
--ckpt_dir ./ckpt_dir/soap_push_1view \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--exclude_cameras camera_right_shoulder camera_left_shoulder \
--lr 2e-5 --seed 0 \
> soap_push_1view.log 2>&1

# %% [markdown]
# Results: 0 / 10
# * Model is confused whether it's retracted or lowering, because it does not model time, and there's no SIDE view to determine that.

# %% [markdown]
# 🔄 Train 6:
# * Model: ACT Base - **Obs joints as Target**
# * Cam Views: 1 views ( wrist)

# %%
python3 imitate_episodes_record_torque.py \
--task_name soap_push \
--ckpt_dir ./ckpt_dir/soap_push_1view_obs_target \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--exclude_cameras camera_right_shoulder camera_left_shoulder \
--lr 2e-5 --seed 0 --use_obs_target \
> soap_push_1view_obs_target.log 2>&1

# %% [markdown]
# Results 0 / 10
# * Same as Train 5
# * One trajectory where it did go down, it could not complete it, since it does not know how much to go down by.

# %% [markdown]
# ### Overview
#
# * Difference between Base and Obs-Tgt is not obvious.
# * Single View absolutely does not work in this setting... seems ACT can NEVER be exposed to the same obs state, or it gets confused, as it has no sense of explicit temporal progression.
