# %% [markdown]
# Soap Push v2 Dataset Experiments.
#
# See the Experiments Google Sheets for details

# %%
python3 imitate_episodes_record_torque.py \
--task_name soap_push \
--ckpt_dir ./ckpt_dir/soap_push \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 \
> soap_push.log 2>&1

# %%
python3 imitate_episodes_record_torque.py \
--task_name soap_push \
--ckpt_dir ./ckpt_dir/soap_push_obs_target \
--robot /home/khw/interbotix_ws/src/aloha/config/robot/aloha_solo \
--policy_class ACT \
--kl_weight 10 \
--chunk_size 100 \
--hidden_dim 512 \
--batch_size 16 \
--dim_feedforward 3200 \
--num_epochs 8000 \
--lr 2e-5 --seed 0 --use_obs_target \
> soap_push_obs_target.log 2>&1
